# %%
import pandas as pd

# %%
df = pd.read_csv("Raw-205 FIRST OUTDOORS-01_29_2021.csv")
df.head()
# Out:
#                      Timezone             Datetime  AQI US  AQI CN  \
# 0  America/New_York UTC-05:00  2021-01-29 20:00:00    1357     491
# 1  America/New_York UTC-05:00  2021-01-29 19:00:00    1357     491
# 2  America/New_York UTC-05:00  2021-01-29 18:00:00    1357     491
# 3  America/New_York UTC-05:00  2021-01-29 17:00:00    1357     491
# 4  America/New_York UTC-05:00  2021-01-29 16:00:00    1357     491
#
#    PM2.5 (ug/m3)  PM10 (ug/m3)  CO2 (ppm)  Temperature (Celsius)  \
# 0           1799          2000      411.0                   -5.0
# 1           1799          2000      412.0                   -5.0
# 2           1799          2000      409.0                   -4.0
# 3           1799          2000      408.0                   -4.0
# 4           1799          2000      407.0                   -2.0
#
#    Temperature (Fahrenheit)  Humidity (%)  Outdoor PM2.5 (ug/m3)  HCHO (ppb)  \
# 0                      23.0          43.0                    NaN         NaN
# ...

# %%
df.to_json("OUTDOORS-01_29_2021.json")
